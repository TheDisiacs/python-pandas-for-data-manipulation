# %% [markdown]
# # Filtering with `AND` & `OR` Operators

# %% [markdown]
# ### Import Pandas

# %%
# import pandas
import pandas as pd
from pathlib import Path
path = Path("C:/Users/alouden01/Documents/python-pandas-for-data-manipulation/starter_files/skill_09_filtering_broadcasting/employee.csv")

# %% [markdown]
# ### Employee data

# %%
emp = pd.read_csv(path, parse_dates=["start_date"])
emp.head(20)
# Out:
#     first_name     last_name  salary start_date       gender  remote  \
# 0      Haleigh    Calderhead  334473 2020-05-09          NaN    True
# 1      Coretta        McEvon  637457 2020-03-20         Male   False
# 2     Clarette       Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime    Gianneschi  253523 2020-09-02     Bigender   False
# 4        Ediva       Skelton  325185 2020-02-04       Female    True
# 5      Auberta  Whistlecraft  510781        NaT   Polygender   False
# 6      Devland     Cominetti  194815 2021-01-16     Bigender   False
# 7        Sarah       Feather  553617 2020-04-05          NaN    True
# 8   Andromache        McAviy  562931 2020-09-15   Non-binary    True
# 9      Susanna      Ivachyov  873134 2020-11-19      Agender   False
# 10        Gray     Ghirigori  972661 2020-05-29          NaN   False
# 11     Malissa       Billett  492837 2020-09-01          NaN   False
# 12        Dani    Withinshaw  152136 2020-11-08  Genderfluid    True
# ...

# %% [markdown]
# ### Head

# %%
# called the head method to see what were working with
eng_mask = emp['team'] == "engineering"
mark_mask = emp['team'] == "marketing"
data_mask = emp['team'] == "data analytics"
emp[eng_mask | mark_mask | data_mask]
# Out:
#     first_name     last_name  salary start_date       gender  remote  \
# 1      Coretta        McEvon  637457 2020-03-20         Male   False
# 2     Clarette       Tarbett  977749 2020-11-22      Agender    True
# 3        Jaime    Gianneschi  253523 2020-09-02     Bigender   False
# 4        Ediva       Skelton  325185 2020-02-04       Female    True
# 5      Auberta  Whistlecraft  510781        NaT   Polygender   False
# ..         ...           ...     ...        ...          ...     ...
# 992        Roy      Axworthy  597997 2020-08-25       Female   False
# 993      Jenny    Ballentime  741738 2020-05-20     Bigender   False
# 994       Myra      Bidewell  908477 2020-08-07  Genderfluid   False
# 998     Jerald       Penella  862555 2020-09-08       Female   False
# 999     Aubrie          Hunt  549364 2020-03-29   Polygender   False
#
#                team
# 1       engineering
# 2       engineering
# 3         marketing
# 4         marketing
# 5       engineering
# ...

# %% [markdown]
# ### Filetring a Series

# %%
emp'gender'.count()
# Out:
#   Cell In[37], line 1
#     emp'gender'.count()
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Brute Force Using the `|` Operator

# %% [markdown]
# ### Filtering with the AND operator: `&`

# %% [markdown]
# ### Filtering with the OR operator: `|`

# %% [markdown]
# ### Extracting with the `&` and `|` Operator Combined
