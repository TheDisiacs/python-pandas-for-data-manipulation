# %% [markdown]
# # Conditional Filtering

# %% [markdown]
# ### Import Pandas

# %%
# import pandas
from email.utils import parsedate
import pandas as pd
from pathlib import Path
path = Path('C:/Users/alouden01/Documents/python-pandas-for-data-manipulation/starter_files/skill_09_filtering_broadcasting/employee.csv')

# %% [markdown]
# ### Employee data

# %%
emp = pd.read_csv(path, parse_dates=['start_date'])

# %% [markdown]
# ### Head

# %%
# called the head method to see what were working with
emp.head()
# Out:
#   first_name   last_name  salary  start_date    gender  remote         team
# 0    Haleigh  Calderhead  334473    5/9/2020       NaN    True   management
# 1    Coretta      McEvon  637457   3/20/2020      Male   False  engineering
# 2   Clarette     Tarbett  977749  11/22/2020   Agender    True  engineering
# 3      Jaime  Gianneschi  253523    9/2/2020  Bigender   False    marketing
# 4      Ediva     Skelton  325185    2/4/2020    Female    True    marketing

# %% [markdown]
# ### Broadcasting Boolean Operations

# %%
# # broadcasting boolean operation: use == and not = ⚠️
female_mask = emp['gender'] == "Female"

# %%
# wrap df[] around the conditional operation to extract the values of the condition
emp[female_mask]
# Out:
#     first_name    last_name  salary  start_date  gender  remote  \
# 4        Ediva      Skelton  325185    2/4/2020  Female    True
# 14      Alfred      Paraman  234494   1/19/2021  Female   False
# 46       Ernst   Fishbourne  994191  10/10/2020  Female    True
# 65       Ivory    MacMaster  848465   10/6/2020  Female   False
# 86      Ingmar       Cuesta  254625  10/29/2020  Female   False
# ..         ...          ...     ...         ...     ...     ...
# 983       Niki       Ivanin  132578  10/27/2020  Female   False
# 984     Carney        Blore  551939    5/6/2020  Female   False
# 988     Ariana  Culverhouse  901497   12/4/2020  Female   False
# 992        Roy     Axworthy  597997   8/25/2020  Female   False
# 998     Jerald      Penella  862555    9/8/2020  Female   False
#
#                team
# 4         marketing
# 14   data analytics
# 46   data analytics
# 65       management
# 86       management
# ..              ...
# 983       marketing
# 984      management
# ...

# %%
# instead of wrapping df[] around the conditional operation, use a variable name
emp['ranked_salary'] = emp['salary'].rank(ascending=False).astype(int)
emp.sort_values('ranked_salary').head()
# Out:
#     first_name    last_name  salary  start_date      gender  remote  \
# 205       Cati  Hendrickson  997426    5/6/2020  Non-binary   False
# 191      Terry        Rives  995927  11/14/2020  Non-binary    True
# 240     Juieta      Alyutin  995710   7/14/2020  Non-binary   False
# 890      Morly     Sheppard  994723   1/16/2021  Non-binary   False
# 46       Ernst   Fishbourne  994191  10/10/2020      Female    True
#
#                team  ranked_salary
# 205       marketing              1
# 191  data analytics              2
# 240  data analytics              3
# 890     engineering              4
# 46   data analytics              5

# %% [markdown]
# ### Filetring with One Condition

# %%
salary_mask = emp['salary'] >= 100000
gender_mask = emp['gender'] == 'Polygender'

# %%
emp[salary_mask].sort_values('ranked_salary', ascending=True).head(20)
# Out:
#     first_name    last_name  salary  start_date       gender  remote  \
# 205       Cati  Hendrickson  997426    5/6/2020   Non-binary   False
# 191      Terry        Rives  995927  11/14/2020   Non-binary    True
# 240     Juieta      Alyutin  995710   7/14/2020   Non-binary   False
# 890      Morly     Sheppard  994723   1/16/2021   Non-binary   False
# 46       Ernst   Fishbourne  994191  10/10/2020       Female    True
# 886       Kile     Edinboro  991993   8/24/2020  Genderqueer   False
# 909     Sarene         Tapp  990676   2/16/2020     Bigender    True
# 66   Isabelita      Giorgio  988088   4/21/2020     Bigender    True
# 903    Mathian        Artus  987505    4/4/2020     Bigender   False
# 84      Cecile  Jerzycowski  987315   9/23/2020          NaN    True
# 42      Blithe     Circuitt  987183   8/11/2020   Polygender   False
# 251     Eberto       Loweth  986711   6/27/2020  Genderqueer   False
# 75     Antonia       Kemery  986028   9/19/2020  Genderqueer    True
# ...

# %%
date_mask = emp['start_date'] < '2020-06-15'
emp[date_mask].sort_values('start_date',ascending=False).head(20)
# Out:
#     first_name  last_name  salary start_date       gender  remote  \
# 281     Morlee    Candlin  964531 2020-06-13   Polygender   False
# 516      Xenia   Sleeford  158945 2020-06-13   Non-binary    True
# 928      Audre  O'Curneen  542744 2020-06-12     Bigender    True
# 712      Sunny  Franzetti  695698 2020-06-12   Non-binary   False
# 245      Ronny    Doughty  250048 2020-06-12  Genderqueer    True
# 272     Virgil  Bernardot  575861 2020-06-12         Male    True
# 236     Hughie    Keysall  949961 2020-06-12         Male   False
# 254       Joel   Taillant  358274 2020-06-11     Bigender   False
# 80       Morna   Sessions  162030 2020-06-11   Non-binary   False
# 950      Bevon     Hlavac  535356 2020-06-09   Polygender    True
# 369     Carmon   Paddison  983876 2020-06-09  Genderfluid   False
# 298      Bella    Renoden  193735 2020-06-08  Genderfluid    True
# 277      Julee    MacKean  297545 2020-06-08   Polygender    True
# ...
