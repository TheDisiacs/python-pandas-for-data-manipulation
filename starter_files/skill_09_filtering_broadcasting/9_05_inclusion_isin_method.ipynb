# %% [markdown]
# # Inclusion `isin()` Method

# %% [markdown]
# ### Import Pandas

# %%
# import pandas
import pandas as pd
from pathlib import Path
path = Path('starter_files/skill_09_filtering_broadcasting/employee.csv')

# %% [markdown]
# ### Employee data

# %%
emp = pd.read_csv(path)

# %% [markdown]
# ### Head

# %%
# called the head method
emp.head()
# Out:
#   first_name   last_name  salary  start_date    gender  remote         team
# 0    Haleigh  Calderhead  334473    5/9/2020       NaN    True   management
# 1    Coretta      McEvon  637457   3/20/2020      Male   False  engineering
# 2   Clarette     Tarbett  977749  11/22/2020   Agender    True  engineering
# 3      Jaime  Gianneschi  253523    9/2/2020  Bigender   False    marketing
# 4      Ediva     Skelton  325185    2/4/2020    Female    True    marketing

# %% [markdown]
# ### The `isin()` Method

# %%
data_mask = emp['team'].isin(['data analytics'])
management_mask = emp['team'].isin(['management'])
emp[data_mask | management_mask]
# Out:
#      first_name   last_name  salary  start_date       gender  remote  \
# 0       Haleigh  Calderhead  334473    5/9/2020          NaN    True
# 7         Sarah     Feather  553617    4/5/2020          NaN    True
# 8    Andromache      McAviy  562931   9/15/2020   Non-binary    True
# 11      Malissa     Billett  492837    9/1/2020          NaN   False
# 12         Dani  Withinshaw  152136   11/8/2020  Genderfluid    True
# ..          ...         ...     ...         ...          ...     ...
# 994        Myra    Bidewell  908477    8/7/2020  Genderfluid   False
# 995      Ysabel  Stollmeyer  649625  10/18/2020   Polygender   False
# 996       Ashby  Threadgold  140806  12/28/2020  Genderfluid   False
# 997     Justino     Asquith  950280  10/26/2020  Genderqueer   False
# 999      Aubrie        Hunt  549364   3/29/2020   Polygender   False
#
#                team
# 0        management
# 7    data analytics
# 8        management
# 11       management
# 12   data analytics
# ...

# %% [markdown]
# ### Extract by Passing `mask` to `df[]`

# %%
# female managers
female_mask = emp['gender'].isin(['Female'])
emp[female_mask & management_mask]
# Out:
#      first_name      last_name  salary  start_date  gender  remote        team
# 65        Ivory      MacMaster  848465   10/6/2020  Female   False  management
# 86       Ingmar         Cuesta  254625  10/29/2020  Female   False  management
# 93    Grenville        Burwell  687303    8/9/2020  Female    True  management
# 142      Aluino          Kubal  413941   7/24/2020  Female    True  management
# 192      Keslie     Benesevich  431890  10/16/2020  Female   False  management
# 208       Conny     Iaduccelli  119264         NaN  Female   False  management
# 239      Sandor        Rogerot  931685   6/27/2020  Female    True  management
# 249      Sayers        Trotter  502059   1/24/2021  Female   False  management
# 344      Ardyce     Stonebanks  364788   8/21/2020  Female   False  management
# 376      Oswald        Jellard  144996   11/6/2020  Female    True  management
# 397      Colver         Camili  812056   1/10/2021  Female   False  management
# ...

# %%
olly_mask = emp['first_name'].isin(['Olly'])
remote_mask = emp['remote'].isin([True])

# %%
emp[female_mask][remote_mask][management_mask]
# Out:
# first_name    17
# last_name     17
# salary        17
# start_date    17
# gender        17
# remote        17
# team          17
# dtype: int64

# %%
n_of_unique = emp['team'].nunique()
# Out:
# 4
