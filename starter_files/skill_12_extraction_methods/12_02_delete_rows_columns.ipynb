# %% [markdown]
# # `.drop( )` method

# %% [markdown]
# ### Import pandas

# %%
# Import pandas
import pandas as pd
from pathlib import Path
path = Path('C:/Users/alouden01/Documents/python-pandas-for-data-manipulation/starter_files/skill_12_extraction_methods/cereal.csv')

# %% [markdown]
# ### Read CSV and set rating index sorted by labels

# %%
cereal = pd.read_csv(path, index_col='name')
cereal.sort_index(inplace=True)
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843

# %% [markdown]
# ### Drop a row from a DataFrame

# %%
cereal.drop('All-Bran')
cereal
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
# ...                          ...     ...     ...       ...    ...     ...
# Triples                     21.0       3      60        25      3     1.0
# Trix                        13.0      12      25        25      2     1.0
# Wheat Chex                  17.0       3     115        25      1     1.0
# Wheaties                    17.0       3     110        25      1     1.0
# Wheaties Honey Gold         16.0       8      60        25      1     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843
# ...                         ...        ...
# Triples                    0.75  39.106174
# Trix                       1.00  27.753301
# Wheat Chex                 0.67  49.787445
# Wheaties                   1.00  51.592193
# Wheaties Honey Gold        0.75  36.187559
#
# [77 rows x 15 columns]

# %% [markdown]
# ### Drop multiple rows

# %%
cereal.drop(['Trix','Triples'])
cereal
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Total Raisin Bran           G    C       140        3    1     190    4.0
# Total Whole Grain           G    C       100        3    1     200    3.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
# ...                          ...     ...     ...       ...    ...     ...
# Total Raisin Bran           15.0      14     230       100      3     1.5
# Total Whole Grain           16.0       3     110       100      3     1.0
# Wheat Chex                  17.0       3     115        25      1     1.0
# Wheaties                    17.0       3     110        25      1     1.0
# Wheaties Honey Gold         16.0       8      60        25      1     1.0
#
#                            cups     rating
# name
# 100% Bran                  0.33  68.402973
# 100% Natural Bran          1.00  33.983679
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Almond Delight             0.75  34.384843
# ...                         ...        ...
# Total Raisin Bran          1.00  28.592785
# Total Whole Grain          1.00  46.658844
# Wheat Chex                 0.67  49.787445
# Wheaties                   1.00  51.592193
# Wheaties Honey Gold        0.75  36.187559
#
# [75 rows x 15 columns]

# %% [markdown]
# ### Remove columns

# %%
cereal.drop(['fat','shelf'], axis='columns' )
# Out:
#                           mfr type  calories  protein  sodium  fiber  carbo  \
# name
# 100% Bran                   N    C        70        4     130   10.0    5.0
# 100% Natural Bran           Q    C       120        3      15    2.0    8.0
# All-Bran                    K    C        70        4     260    9.0    7.0
# All-Bran with Extra Fiber   K    C        50        4     140   14.0    8.0
# Almond Delight              R    C       110        2     200    1.0   14.0
# ...                        ..  ...       ...      ...     ...    ...    ...
# Triples                     G    C       110        2     250    0.0   21.0
# Trix                        G    C       110        1     140    0.0   13.0
# Wheat Chex                  R    C       100        3     230    3.0   17.0
# Wheaties                    G    C       100        3     200    3.0   17.0
# Wheaties Honey Gold         G    C       110        2     200    1.0   16.0
#
#                            sugars  potass  vitamins  weight  cups     rating
# name
# 100% Bran                       6     280        25     1.0  0.33  68.402973
# 100% Natural Bran               8     135         0     1.0  1.00  33.983679
# All-Bran                        5     320        25     1.0  0.33  59.425505
# All-Bran with Extra Fiber       0     330        25     1.0  0.50  93.704912
# Almond Delight                  8      -1        25     1.0  0.75  34.384843
# ...                           ...     ...       ...     ...   ...        ...
# Triples                         3      60        25     1.0  0.75  39.106174
# Trix                           12      25        25     1.0  1.00  27.753301
# Wheat Chex                      3     115        25     1.0  0.67  49.787445
# Wheaties                        3     110        25     1.0  1.00  51.592193
# Wheaties Honey Gold             8      60        25     1.0  0.75  36.187559
#
# [77 rows x 13 columns]

# %% [markdown]
# ### Keeping it Pythonic

# %%
# del cereal['type']
cereal
# Out:
#                           mfr  calories  protein  fat  sodium  fiber  carbo  \
# name
# 100% Bran                   N        70        4    1     130   10.0    5.0
# 100% Natural Bran           Q       120        3    5      15    2.0    8.0
# All-Bran                    K        70        4    1     260    9.0    7.0
# All-Bran with Extra Fiber   K        50        4    0     140   14.0    8.0
# Almond Delight              R       110        2    2     200    1.0   14.0
# ...                        ..       ...      ...  ...     ...    ...    ...
# Triples                     G       110        2    1     250    0.0   21.0
# Trix                        G       110        1    1     140    0.0   13.0
# Wheat Chex                  R       100        3    1     230    3.0   17.0
# Wheaties                    G       100        3    1     200    3.0   17.0
# Wheaties Honey Gold         G       110        2    1     200    1.0   16.0
#
#                            sugars  potass  vitamins  shelf  weight  cups  \
# name
# 100% Bran                       6     280        25      3     1.0  0.33
# 100% Natural Bran               8     135         0      3     1.0  1.00
# All-Bran                        5     320        25      3     1.0  0.33
# All-Bran with Extra Fiber       0     330        25      3     1.0  0.50
# Almond Delight                  8      -1        25      3     1.0  0.75
# ...                           ...     ...       ...    ...     ...   ...
# Triples                         3      60        25      3     1.0  0.75
# Trix                           12      25        25      2     1.0  1.00
# Wheat Chex                      3     115        25      1     1.0  0.67
# Wheaties                        3     110        25      1     1.0  1.00
# Wheaties Honey Gold             8      60        25      1     1.0  0.75
#
#                               rating
# name
# 100% Bran                  68.402973
# 100% Natural Bran          33.983679
# All-Bran                   59.425505
# All-Bran with Extra Fiber  93.704912
# Almond Delight             34.384843
# ...                              ...
# Triples                    39.106174
# Trix                       27.753301
# Wheat Chex                 49.787445
# Wheaties                   51.592193
# Wheaties Honey Gold        36.187559
#
# [77 rows x 14 columns]

# %%
del(cereal=['fat'])
# Out:
#   Cell In[14], line 1
#     del(cereal=['fat'])
#         ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
