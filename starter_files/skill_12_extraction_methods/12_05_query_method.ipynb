# %% [markdown]
# # `.query()` method

# %% [markdown]
# ### Import pandas

# %%
# Import pandas
import pandas as pd
from pathlib import Path
path = Path('C:/Users/alouden01/Documents/python-pandas-for-data-manipulation/starter_files/skill_12_extraction_methods/cereal.csv')

# %% [markdown]
# ### Read CSV and set rating index sorted by labels

# %%
cereal = pd.read_csv(path, index_col='name')
cereal.sort_index(inplace=True)
cereal.head()
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# 100% Bran                    5.0       6     280        25      3     1.0
# 100% Natural Bran            8.0       8     135         0      3     1.0
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Almond Delight              14.0       8      -1        25      3     1.0
#
#                            cups     rating
# name
# ...

# %%
# check out the query method documentation first


cereal.query("mfr == 'K'")
# Out:
#                             mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran                      K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber     K    C        50        4    0     140   14.0
# Apple Jacks                   K    C       110        2    0     125    1.0
# Corn Flakes                   K    C       100        2    0     290    1.0
# Corn Pops                     K    C       110        1    0      90    1.0
# Cracklin' Oat Bran            K    C       110        3    3     140    4.0
# Crispix                       K    C       110        2    0     220    1.0
# Froot Loops                   K    C       110        2    1     125    1.0
# Frosted Flakes                K    C       110        1    0     200    1.0
# Frosted Mini-Wheats           K    C       100        3    0       0    3.0
# Fruitful Bran                 K    C       120        3    0     240    5.0
# ...

# %%
cereal.query('carbo > 10').sort_values('carbo')
# Out:
#                         mfr type  calories  protein  fat  sodium  fiber  \
# name
# Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# Raisin Nut Bran           G    C       100        3    2     140    2.5
# Froot Loops               K    C       110        2    1     125    1.0
# Apple Jacks               K    C       110        2    0     125    1.0
# Golden Crisp              P    C       100        2    0      45    0.0
# ...                      ..  ...       ...      ...  ...     ...    ...
# Triples                   G    C       110        2    1     250    0.0
# Total Corn Flakes         G    C       110        2    1     200    0.0
# Corn Chex                 R    C       110        2    0     280    0.0
# Rice Krispies             K    C       110        2    0     290    0.0
# Rice Chex                 R    C       110        1    0     240    0.0
#
#                          carbo  sugars  potass  vitamins  shelf  weight  cups  \
# name
# ...

# %%
mask_drop = cereal.query('mfr == "K" and carbo < 10').sort_values("carbo")
mask_drop
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Smacks                      K    C       110        2    1      70    1.0
#
#                            carbo  sugars  potass  vitamins  shelf  weight  \
# name
# All-Bran                     7.0       5     320        25      3     1.0
# All-Bran with Extra Fiber    8.0       0     330        25      3     1.0
# Smacks                       9.0      15      40        25      2     1.0
#
#                            cups     rating
# name
# All-Bran                   0.33  59.425505
# All-Bran with Extra Fiber  0.50  93.704912
# Smacks                     0.75  31.230054

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30452\1159559311.py in ?()
# ----> 1 mask_3 = mask_drop == cereal
#       2 mask_3
#
# c:\Users\alouden01\AppData\Local\anaconda3\envs\pandas_cbtn\Lib\site-packages\pandas\core\ops\common.py in ?(self, other)
#      72                     return NotImplemented
#      73
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#
# c:\Users\alouden01\AppData\Local\anaconda3\envs\pandas_cbtn\Lib\site-packages\pandas\core\arraylike.py in ?(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#
# c:\Users\alouden01\AppData\Local\anaconda3\envs\pandas_cbtn\Lib\site-packages\pandas\core\frame.py in ?(self, other, op)
# ...
