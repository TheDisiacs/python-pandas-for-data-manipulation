# %% [markdown]
# # Sort by values `sort_values()`

# %% [markdown]
# ### Import Pandas

# %%
# Import pandas
import pandas as pd

# %% [markdown]
# ### Read CSV as Series

# %%
from pathlib import Path
path = Path('C:/Users/alouden01/Documents/python-pandas-for-data-manipulation/starter_files/skill_04_series_attributes_methods/animal_names.csv')
a = pd.read_csv(path,usecols=['country']).squeeze()
a
# Out:
# 0       Azerbaijan
# 1       Kazakhstan
# 2            China
# 3      Philippines
# 4         Cambodia
#           ...
# 995          China
# 996          China
# 997         Poland
# 998         Angola
# 999         Canada
# Name: country, Length: 1000, dtype: object

# %% [markdown]
# ### Sort by Values `sort_values()`

# %%
# sorting a Series alphabetically
a = pd.read_csv(path, usecols=['country']).squeeze('columns')
a
# Out:
# 0       Azerbaijan
# 1       Kazakhstan
# 2            China
# 3      Philippines
# 4         Cambodia
#           ...
# 995          China
# 996          China
# 997         Poland
# 998         Angola
# 999         Canada
# Name: country, Length: 1000, dtype: object

# %% [markdown]
# ### Method Chain

# %%
# a useful method chain
a.head()
a.sort_values()
# Out:
# 983    Afghanistan
# 581    Afghanistan
# 328    Afghanistan
# 533    Afghanistan
# 876    Afghanistan
#           ...
# 700          Yemen
# 283          Yemen
# 268          Yemen
# 11           Yemen
# 655          Yemen
# Name: country, Length: 1000, dtype: object

# %% [markdown]
# ### `sort_values()` parameters

# %%
# hold shift + tab inside of method
a.sort_values()
a_ser = a

# %%
a
# Out:
# 0       Azerbaijan
# 1       Kazakhstan
# 2            China
# 3      Philippines
# 4         Cambodia
#           ...
# 995          China
# 996          China
# 997         Poland
# 998         Angola
# 999         Canada
# Name: country, Length: 1000, dtype: object

# %%
a.sort_values()
# Out:
# 983    Afghanistan
# 581    Afghanistan
# 328    Afghanistan
# 533    Afghanistan
# 876    Afghanistan
#           ...
# 700          Yemen
# 283          Yemen
# 268          Yemen
# 11           Yemen
# 655          Yemen
# Name: country, Length: 1000, dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
sort(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sort(a)
#
# NameError: name 'sort' is not defined

# %%
sorted(a)
# Out:
# ['Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Albania',
#  'Angola',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Armenia',
#  'Australia',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Azerbaijan',
#  'Bangladesh',
#  'Belarus',
#  'Belarus',
#  'Benin',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Bosnia and Herzegovina',
#  'Bosnia and Herzegovina',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Botswana',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
#  'Brazil',
# ...

# %%
a.sort_values().head(7)
# Out:
# 983    Afghanistan
# 581    Afghanistan
# 328    Afghanistan
# 533    Afghanistan
# 876    Afghanistan
# 182        Albania
# 998         Angola
# Name: country, dtype: object
