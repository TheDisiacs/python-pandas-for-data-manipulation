# %% [markdown]
# # Strip methods

# %% [markdown]
# ### Import pandas

# %%
import pandas as pd
from pathlib import Path
path = Path('C:/Users/alouden01/Documents/python-pandas-for-data-manipulation/starter_files/skill_14_splitting_stripping_text_data/StudentsPerfomrance_whitespace.csv')

# %% [markdown]
# ### Read CSV
# Let's revisit the optimized dataset for lower the memory usage and try to remove the whitespace using a strip method. I've added some extra whitespace and created a new csv: `StudentsPerfomrance_whitespace.csv`

# %%
students = pd.read_csv(path)
students.head()
# Out:
#        gender race/ethnicity parental level of education              lunch  \
# 0     female         group B           bachelor's degree          standard
# 1     female         group C                some college          standard
# 2     female         group B             master's degree          standard
# 3       male         group A          associate's degree      free/reduced
# 4       male         group C                some college          standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
students.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %% [markdown]
# ### Review the `.replace( )` method

# %%
# for s in students:
#     if students[s].dtype == object:
#         students[s] = students[s].str.replace(' ','_')
students.head()
# Out:
#        gender race/ethnicity parental level of education              lunch  \
# 0     female         group B           bachelor's degree          standard
# 1     female         group C                some college          standard
# 2     female         group B             master's degree          standard
# 3       male         group A          associate's degree      free/reduced
# 4       male         group C                some college          standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# why does it say standard has 13 characters? Probably whitespace ⚠️

# %%
# why does "female" contain 10 characters? Probably whitespace ⚠️

# %%
# way to go, you found and removed whitespace hidden in the lunch column

# %%
# we could use the replace method but there is a better way

# %% [markdown]
# ### The `strip( )`, `lstrip( )`, and  `rstrip()` methods

# %%
# lstrip() remove whitespace on the left

# %%
# rstrip() remove whitespace on the right

# %%
# finally, strip() removes all white space (lstrip + rstrip)
for col_name, col_data in students.items():
    print(type(col_name), type(col_data))
    print(col_data.values)
# Out:
# <class 'str'> <class 'pandas.core.series.Series'>
# ['   female ' '   female ' '   female ' '   male ' '   male ' '   female '
#  '   female ' '   male ' '   male ' '   female ' '   male ' '   male '
#  '   female ' '   male ' '   female ' '   female ' '   male ' '   female '
#  '   male ' '   female ' '   male ' '   female ' '   male ' '   female '
#  '   male ' '   male ' '   male ' '   female ' '   male ' '   female '
#  '   female ' '   female ' '   female ' '   male ' '   male ' '   male '
#  '   female ' '   female ' '   female ' '   male ' '   male ' '   female '
#  '   female ' '   male ' '   female ' '   male ' '   female ' '   female '
#  '   female ' '   male ' '   male ' '   male ' '   male ' '   male '
#  '   female ' '   female ' '   female ' '   male ' '   male ' '   female '
#  '   male ' '   male ' '   male ' '   female ' '   female ' '   male '
#  '   male ' '   female ' '   male ' '   female ' '   female ' '   male '
# ...

# %%
# note that it doesn't remove the whitespace in between

# %% [markdown]
# ### Remove whitespace for the gender column

# %%
# remove whitespace on the left and right for

# %% [markdown]
# ### Remove whitespace for the lunch column
