# %% [markdown]
# # Return rows by index positions with `.iloc[ ]`

# %% [markdown]
# ### Import pandas

# %%
# Import pandas
import pandas as pd
from pathlib import Path


path = ('C:/Users/alouden01/Documents/python-pandas-for-data-manipulation/starter_files/skill_11_extracting_values/cereal.csv')

# %% [markdown]
# ### Read CSV
# We'll continue with the 80 Cereals dataset and this time we'll keep the numeric index and not use the name lable, like we did with `.loc[ ] `.

# %%
df = pd.read_csv(path)
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %% [markdown]
# ### Indexing with `iloc[ ]`

# %%
# sytax is much like .loc[ ], here we have the first row
df.iloc[0]
# Out:
# name        100% Bran
# mfr                 N
# type                C
# calories           70
# protein             4
# fat                 1
# sodium            130
# fiber            10.0
# carbo             5.0
# sugars              6
# potass            280
# vitamins           25
# shelf               3
# weight            1.0
# cups             0.33
# rating      68.402973
# Name: 0, dtype: object

# %%
# here we ahve the last row using the negative index position of -1
df.iloc[-1]
# Out:
# name        Wheaties Honey Gold
# mfr                           G
# type                          C
# calories                    110
# protein                       2
# fat                           1
# sodium                      200
# fiber                       1.0
# carbo                      16.0
# sugars                        8
# potass                       60
# vitamins                     25
# shelf                         1
# weight                      1.0
# cups                       0.75
# rating                36.187559
# Name: 76, dtype: object

# %% [markdown]
# ### Slicing with `.iloc[ ]`

# %%
# iloc[] is not inclusive, so keep that in mind!
df.iloc[5:10]
# Out:
#                       name mfr type  calories  protein  fat  sodium  fiber  \
# 5  Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6              Apple Jacks   K    C       110        2    0     125    1.0
# 7                  Basic 4   G    C       130        3    2     210    2.0
# 8                Bran Chex   R    C        90        2    1     200    4.0
# 9              Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 5   10.5      10      70        25      1    1.00  0.75  29.509541
# 6   11.0      14      30        25      2    1.00  1.00  33.174094
# 7   18.0       8     100        25      3    1.33  0.75  37.038562
# 8   15.0       6     125        25      1    1.00  0.67  49.120253
# 9   13.0       5     190        25      3    1.00  0.67  53.313813

# %%
# you can also slice like this
df.iloc[:]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %%
df.iloc[[10,15,32]]
# Out:
#                  name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 10       Cap'n'Crunch   Q    C       120        1    2     220    0.0   12.0
# 15          Corn Chex   R    C       110        2    0     280    0.0   22.0
# 32  Grape Nuts Flakes   P    C       100        3    1     140    3.0   15.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 10      12      35        25      2     1.0  0.75  18.042851
# 15       3      25        25      1     1.0  1.00  41.445019
# 32       5      85        25      3     1.0  0.88  52.076897

# %% [markdown]
# ### Return multiple rows by index

# %%
# this dataset only contains 77 cereals, not 80, so beware

# %% [markdown]
# ### Returning multiple indexes

# %%
# order matters

# %% [markdown]
# ### Return specific columns for an index label

# %%
cereal = df
cereal.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
# you can also return mulpitle rows with specific columns
cereal.iloc[[3,9,13],[0,3,7,8]]
# Out:
#                          name  calories  fiber  carbo
# 3   All-Bran with Extra Fiber        50   14.0    8.0
# 9                 Bran Flakes        90    5.0   13.0
# 13                   Clusters       110    2.0   13.0

# %% [markdown]
# ### You can also leverage slicing!

# %%
cereal.loc[[1,2,3],['name','calories','fiber','carbo']]
# Out:
#                         name  calories  fiber  carbo
# 1          100% Natural Bran       120    2.0    8.0
# 2                   All-Bran        70    9.0    7.0
# 3  All-Bran with Extra Fiber        50   14.0    8.0

# %%
cereal
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %%
# what is this?
