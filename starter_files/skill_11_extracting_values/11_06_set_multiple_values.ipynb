# %% [markdown]
# # Set multiple values in a particular row

# %% [markdown]
# ### Import pandas

# %%
# Import pandas
import pandas as pd
from pathlib import Path
path = Path('C:/Users/alouden01/Documents/python-pandas-for-data-manipulation/starter_files/skill_11_extracting_values/cereal.csv')

# %% [markdown]
# ### Read CSV and set rating index sorted by labels

# %%
cereal = pd.read_csv(path,index_col='name')
cereal.sort_index(inplace=True)
cereal
# Out:
#                           mfr type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N    C        70        4    1     130   10.0
# 100% Natural Bran           Q    C       120        3    5      15    2.0
# All-Bran                    K    C        70        4    1     260    9.0
# All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# Almond Delight              R    C       110        2    2     200    1.0
# ...                        ..  ...       ...      ...  ...     ...    ...
# Triples                     G    C       110        2    1     250    0.0
# Trix                        G    C       110        1    1     140    0.0
# Wheat Chex                  R    C       100        3    1     230    3.0
# Wheaties                    G    C       100        3    1     200    3.0
# Wheaties Honey Gold         G    C       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### Set multiple values from "C" to "cereal"

# %%
cereal_type = cereal['type'] == "C"

# %%
cereal_type
# Out:
# name
# 100% Bran                    True
# 100% Natural Bran            True
# All-Bran                     True
# All-Bran with Extra Fiber    True
# Almond Delight               True
#                              ...
# Triples                      True
# Trix                         True
# Wheat Chex                   True
# Wheaties                     True
# Wheaties Honey Gold          True
# Name: type, Length: 77, dtype: bool

# %%
cereal
# Out:
#                           mfr    type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N  Cereal        70        4    1     130   10.0
# 100% Natural Bran           Q  Cereal       120        3    5      15    2.0
# All-Bran                    K  Cereal        70        4    1     260    9.0
# All-Bran with Extra Fiber   K  Cereal        50        4    0     140   14.0
# Almond Delight              R  Cereal       110        2    2     200    1.0
# ...                        ..     ...       ...      ...  ...     ...    ...
# Triples                     G  Cereal       110        2    1     250    0.0
# Trix                        G  Cereal       110        1    1     140    0.0
# Wheat Chex                  R  Cereal       100        3    1     230    3.0
# Wheaties                    G  Cereal       100        3    1     200    3.0
# Wheaties Honey Gold         G  Cereal       110        2    1     200    1.0
#
# ...

# %% [markdown]
# ### With `.iloc[ ]`

# %%
carby = cereal['carbo'] > 10
carby
# Out:
# name
# 100% Bran                    False
# 100% Natural Bran            False
# All-Bran                     False
# All-Bran with Extra Fiber    False
# Almond Delight                True
#                              ...
# Triples                       True
# Trix                          True
# Wheat Chex                    True
# Wheaties                      True
# Wheaties Honey Gold           True
# Name: carbo, Length: 77, dtype: bool

# %%
cereal['carby'] = 'Not too many carbs'
cereal.loc[carby, 'carby'] = 'Too many carbs!!!'
cereal
# Out:
#                           mfr    type  calories  protein  fat  sodium  fiber  \
# name
# 100% Bran                   N  Cereal        70        4    1     130   10.0
# 100% Natural Bran           Q  Cereal       120        3    5      15    2.0
# All-Bran                    K  Cereal        70        4    1     260    9.0
# All-Bran with Extra Fiber   K  Cereal        50        4    0     140   14.0
# Almond Delight              R  Cereal       110        2    2     200    1.0
# ...                        ..     ...       ...      ...  ...     ...    ...
# Triples                     G  Cereal       110        2    1     250    0.0
# Trix                        G  Cereal       110        1    1     140    0.0
# Wheat Chex                  R  Cereal       100        3    1     230    3.0
# Wheaties                    G  Cereal       100        3    1     200    3.0
# Wheaties Honey Gold         G  Cereal       110        2    1     200    1.0
#
# ...

# %%
# verify
